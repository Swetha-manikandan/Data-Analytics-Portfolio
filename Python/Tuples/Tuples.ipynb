# %%
T = (12.5,3,"ABC")
T[1]
print(T[1])

a = (1,2,1,3)
print(a.count(1))
print(a.index(1))

S = (10,11,26,25,24)
print(S[0])
print(S[4])

fruits = ('apple', 'banana', 'Orange','mango')
# Out:
# 3
# 2
# 0
# 10
# 24
