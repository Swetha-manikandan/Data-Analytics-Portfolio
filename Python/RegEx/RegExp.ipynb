# %%
import re
text="A regex pattern to search for; can be simple text or a complex expression.The target string where the pattern is searched.Modifiers that change matching behavior"
res=re.search('is',text)
print(res)
# Out:
# <re.Match object; span=(110, 112), match='is'>

# %%
import re
text="A regex pattern to  the search for; can be simple text or a complex expression.The target string where the pattern is searched. The Modifiers that change matching behavior"
res=re.findall('the',text)
print(res)
# Out:
# ['the', 'the']

# %%
import re
text="Power Bi"
res=re.sub('Power Bi','PowerBI',text)
print(res)
# Out:
# PowerBI

# %%
import re
text = "Order123"
data = re.findall('\d',text)
print(data)
# Out:
# ['1', '2', '3']

# %%
import re
text = "Order123"
data = re.findall('[a-z]',text)
print(data)
# Out:
# ['r', 'd', 'e', 'r']

# %%
import re
text = "Order123"
data = re.findall('[A-Z]',text)
print(data)
# Out:
# ['O']

# %%
import re
text = "Order123"
data = re.findall('\d+',text)
print(data)
# Out:
# ['123']

# %%
import re
text = "Sales:500 Profit:100"
data = re.findall('\d+',text)
print(data)
# Out:
# ['500', '100']

# %%
import re
mailid = "john123@gmail.com"
data = re.search('\w@\w.\w',mailid)
print(data)
# Out:
# <re.Match object; span=(6, 11), match='3@gma'>

# %%
import re
mailid = "john123@gmail.com"
data = re.findall(r'\w+@\w+.\w+',mailid)
print(data)
# Out:
# ['john123@gmail.com']

# %%
import re
phnno = '9892682066'
data = re.search('\d{10}',phnno)
print(data)
# Out:
# <re.Match object; span=(0, 10), match='9892682066'>

# %%
import re
phnno = '9892682066'
data = re.findall('\d{10}',phnno)
print(data)
# Out:
# ['9892682066']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
