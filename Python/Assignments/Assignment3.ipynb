# %%
a = "joHn sMith"
a.strip()
print(a.upper())
print(a.lower())
print(a.title())
print(len(a))
# Out:
# JOHN SMITH
# john smith
# John Smith
# 10

# %%
customers = ["John", "Mary", "David"]
customers.append("Lily")
print(customers)
# Out:
# ['John', 'Mary', 'David', 'Lily']

# %%
customers = ["John", "Mary", "David", "Lily"]
customers.remove("Mary")
print(customers)
# Out:
# ['John', 'David', 'Lily']

# %%
customers = ["John", "Mary", "David", "Lily"]
customers.sort()
print(customers)
# Out:
# ['David', 'John', 'Lily', 'Mary']

# %%
customers = ["John", "Mary", "David", "Lily"]
print(len(customers))
# Out:
# 4

# %%
customers = ["John", "Mary", "David", "Lily"]
print(customers[0])
print(customers[3])
# Out:
# John
# Lily
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Display all values.
# Access individual elements.
# Display company age
